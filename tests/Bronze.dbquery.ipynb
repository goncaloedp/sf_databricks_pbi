-- %%
SELECT * 
FROM sf_ativos
LIMIT 25;

SELECT * 
FROM sf_ct_me
LIMIT 25;

SELECT * 
FROM sf_empresa
LIMIT 25;

SELECT * 
FROM sf_equipamentos_me
LIMIT 25;

SELECT * 
FROM sf_eventos
LIMIT 25;

SELECT * 
FROM sf_obra
LIMIT 25;

SELECT * 
FROM sf_pedidos_operacao
LIMIT 25;

SELECT * 
FROM sf_sintomas_eventos_pai
LIMIT 25;

SELECT * 
FROM sf_tomadas_me
LIMIT 25;
